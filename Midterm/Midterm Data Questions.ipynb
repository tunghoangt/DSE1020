# %%
#Question 1: Unsupervised learning

#KMeans
from sklearn.cluster import KMeans
#Standard Scaler (for different scaled variables)
from sklearn.preprocessing import StandardScaler

#Standard Scaler: transform each feature to have mean 0 and variance 1
scaler = StandardScaler()
#Transform:
scaler.fit(samples)
samples_scaled = scaler.transform(samples)

#Set up Kmeans
model = KMeans(n_clusters = 3)
label = model.fit_predict(samples_scaled)

#Crosstab table:
ct = pd.crosstab(df['labels'], df['species'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-534245e77d35> in <module>()
#       9 scaler = StandardScaler()
#      10 #Transform:
# ---> 11 scaler.fit(samples)
#      12 samples_scaled = scaler.transform(samples)
#      13
#
# NameError: name 'samples' is not defined

# %%
#PCA decorrelate the features of the dataset

# Import PCA
from sklearn.decomposition import PCA

# Create PCA instance: model
model = PCA(n_components=2)

# Apply the fit_transform method of model to grains: pca_features
pca_features = model.fit_transform(grains)

# Assign 0th column of pca_features: xs
xs = pca_features[:,0]

# Assign 1st column of pca_features: ys
ys = pca_features[:,1]

# Scatter plot xs vs ys
plt.scatter(xs, ys)
plt.axis('equal')
plt.show()

# Calculate the Pearson correlation of xs and ys to ensure that it's 0 (Decorrelated)
correlation, pvalue = pearsonr(xs, ys)

# Display the correlation
print(correlation)

===
# Perform the necessary imports
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt

# Create scaler: scaler
scaler = StandardScaler()

# Create a PCA instance: pca
pca = PCA()

# Create pipeline: pipeline
pipeline = make_pipeline(scaler,pca)

# Fit the pipeline to 'samples'
pipeline.fit(samples)

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()


--
In a previous exercise, you saw that 2 was a reasonable choice for the "intrinsic dimension" of the fish measurements. 
Now use PCA for dimensionality reduction of the fish measurements, retaining only the 2 most important components.

The fish measurements have already been scaled for you, and are available as scaled_samples.
--
# Import PCA
from sklearn.decomposition import PCA

# Create a PCA model with 2 components: pca
pca = PCA(n_components=2)

# Fit the PCA instance to the scaled samples
pca.fit(scaled_samples)

# Transform the scaled samples: pca_features
pca_features = pca.transform(scaled_samples)

# Print the shape of pca_features
print(pca_features.shape)
